# %% [markdown]
# <a href="https://colab.research.google.com/github/rudmaxx/DTA_Python/blob/main/clasmade/Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Function Python
#
# ```
# def name_func():
#   pass
# ```
